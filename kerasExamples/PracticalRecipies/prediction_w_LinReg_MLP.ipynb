# %%
import numpy as np

# 데이터셋 생성
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 데이터셋 확인
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(x_train, y_train, 'ro')
plt.plot(x_test, y_test, 'bo')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Linear Regression Model

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from sklearn.metrics import mean_squared_error
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

x_train = x_train.reshape(1000,)
y_train = y_train.reshape(1000,)
x_test = x_test.reshape(100,)
y_test = y_test.reshape(100,)

# 2. 모델 구성하기
w = np.cov(x_train, y_train, bias=1)[0,1] / np.var(x_train)
b = np.average(y_train) - w * np.average(x_train)

print( w, b)

# 3. 모델 평가하기
y_predict = w * x_test + b
mse = mean_squared_error(y_test, y_predict)
print('mse : ' + str(mse))
# Out:
# 1.990279631787405 0.16948479516329562
# mse : 0.011441868045336489

# %% [markdown]
# ## Perceptron

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(1, input_dim=1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)
w, b = model.get_weights()
print (w, b)
# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Using TensorFlow backend.
# Epoch 1/50
# 1000/1000 [==============================] - 0s 141us/step - loss: 4.7110
# Epoch 2/50
# 1000/1000 [==============================] - 0s 15us/step - loss: 4.5941
# Epoch 3/50
# 1000/1000 [==============================] - 0s 14us/step - loss: 4.4943
# Epoch 4/50
# 1000/1000 [==============================] - 0s 14us/step - loss: 4.3968
# Epoch 5/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 4.3009
# Epoch 6/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 4.2065
# Epoch 7/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 4.1142
# Epoch 8/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 4.0224
# Epoch 9/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 3.9315
# Epoch 10/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 3.8424
# Epoch 11/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 3.7552
# Epoch 12/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 3.6674
# Epoch 13/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 3.5815
# Epoch 14/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 3.4966
# Epoch 15/50
# 1000/1000 [==============================] - 0s 41us/step - loss: 3.4132
# Epoch 16/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 3.3305
# Epoch 17/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 3.2494
# Epoch 18/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 3.1694
# Epoch 19/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 3.0903
# Epoch 20/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 3.0124
# Epoch 21/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 2.9356
# Epoch 22/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 2.8603
# Epoch 23/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 2.7858
# Epoch 24/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 2.7128
# Epoch 25/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 2.6414
# Epoch 26/50
# 1000/1000 [==============================] - 0s 15us/step - loss: 2.5703
# Epoch 27/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 2.5011
# Epoch 28/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 2.4329
# Epoch 29/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 2.3651
# Epoch 30/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 2.2987
# Epoch 31/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 2.2340
# Epoch 32/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 2.1704
# Epoch 33/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 2.1074
# Epoch 34/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 2.0460
# Epoch 35/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 1.9861
# Epoch 36/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 1.9268
# Epoch 37/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 1.8685
# Epoch 38/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 1.8112
# Epoch 39/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 1.7548
# Epoch 40/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 1.7004
# Epoch 41/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 1.6476
# Epoch 42/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 1.5957
# Epoch 43/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 1.5447
# Epoch 44/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 1.4946
# Epoch 45/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 1.4457
# Epoch 46/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 1.3982
# Epoch 47/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 1.3514
# Epoch 48/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 1.3064
# Epoch 49/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 1.2621
# Epoch 50/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 1.2192
# [[-0.79316556]] [0.7972826]
# 100/100 [==============================] - 0s 235us/step
# loss : 1.1989194935560226

# %% [markdown]
# ## MLP

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(64, input_dim=1, activation='relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 0s 164us/step - loss: 1.1891
# Epoch 2/50
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.8257
# Epoch 3/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.5692
# Epoch 4/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.3669
# Epoch 5/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.2159
# Epoch 6/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1171
# Epoch 7/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0680
# Epoch 8/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0507
# Epoch 9/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0410
# Epoch 10/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0313
# Epoch 11/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0230
# Epoch 12/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0167
# Epoch 13/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0127
# Epoch 14/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0110
# Epoch 15/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0101
# Epoch 16/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0100
# Epoch 17/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0099
# Epoch 18/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0099
# Epoch 19/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0100
# Epoch 20/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0099
# Epoch 21/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0098
# Epoch 22/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0098
# Epoch 23/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0098
# Epoch 24/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0098
# Epoch 25/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0098
# Epoch 26/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0099
# Epoch 27/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0099
# Epoch 28/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0098
# Epoch 29/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0098
# Epoch 30/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0099
# Epoch 31/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0099
# Epoch 32/50
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0099
# Epoch 33/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0099
# Epoch 34/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0099
# Epoch 35/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0099
# Epoch 36/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0099
# Epoch 37/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0099
# Epoch 38/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0099
# Epoch 39/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0100
# Epoch 40/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0098
# Epoch 41/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0099
# Epoch 42/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0098
# Epoch 43/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0098
# Epoch 44/50
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0098
# Epoch 45/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0099
# Epoch 46/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0098
# Epoch 47/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0099
# Epoch 48/50
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0098
# Epoch 49/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0099
# Epoch 50/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0099
# 100/100 [==============================] - 0s 374us/step
# loss : 0.009750398714095354

# %% [markdown]
# ## DEEP MLP
# ### one extra layer..

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(64, input_dim=1, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 0s 212us/step - loss: 1.3199
# Epoch 2/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.4263
# Epoch 3/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0908
# Epoch 4/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0341
# Epoch 5/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0219
# Epoch 6/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0131
# Epoch 7/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0105
# Epoch 8/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0099
# Epoch 9/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0099
# Epoch 10/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0098
# Epoch 11/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0101
# Epoch 12/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0099
# Epoch 13/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0102
# Epoch 14/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0101
# Epoch 15/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0100
# Epoch 16/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0099
# Epoch 17/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0101
# Epoch 18/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0100
# Epoch 19/50
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0100
# Epoch 20/50
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0097
# Epoch 21/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0103
# Epoch 22/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0098
# Epoch 23/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0101
# Epoch 24/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0101
# Epoch 25/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0096
# Epoch 26/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0103
# Epoch 27/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0100
# Epoch 28/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0099
# Epoch 29/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0104
# Epoch 30/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0098
# Epoch 31/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0100
# Epoch 32/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0102
# Epoch 33/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0098
# Epoch 34/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0101
# Epoch 35/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0101
# Epoch 36/50
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.0098
# Epoch 37/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0103
# Epoch 38/50
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0098
# Epoch 39/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0104
# Epoch 40/50
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0099
# Epoch 41/50
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0099
# Epoch 42/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0098
# Epoch 43/50
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0103
# Epoch 44/50
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0099
# Epoch 45/50
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0100
# Epoch 46/50
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0100
# Epoch 47/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0100
# Epoch 48/50
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0100
# Epoch 49/50
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.0101
# Epoch 50/50
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0099
# 100/100 [==============================] - 0s 571us/step
# loss : 0.008772217109799385
